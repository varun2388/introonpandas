# %% [markdown]
# <a href="https://colab.research.google.com/github/varun2388/introonpandas/blob/main/introonpandas_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#to display first 5 records in dataset
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
# to tell us how many columns and rows are there
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
# prompt: import pandas library , read this file /content/Salaries.csv, can you aplly functions like head , tail , type , and attributes like shape, columns and also check for null values in this dataset

import pandas as pd

# Read the CSV file
df = pd.read_csv('/content/Salaries.csv')

# Display the first 5 rows
print("Head of the DataFrame:")
print(df.head())

# Display the last 5 rows
print("\nTail of the DataFrame:")
print(df.tail())

# Display the shape of the DataFrame
print("\nShape of the DataFrame:", df.shape)

# Display the column names
print("\nColumns of the DataFrame:", df.columns)

# Display the type of the DataFrame
print("\nType of the DataFrame:", type(df))

# Check for null values
print("\nNull values in the DataFrame:")
print(df.isnull())

# Display sum of null values for each column
print("\nSum of null values for each column:")
print(df.isnull().sum())
# Out:
# Head of the DataFrame:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800
#
# Tail of the DataFrame:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# Shape of the DataFrame: (78, 6)
#
# Columns of the DataFrame: Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')
#
# Type of the DataFrame: <class 'pandas.core.frame.DataFrame'>
#
# Null values in the DataFrame:
#      rank  discipline    phd  service    sex  salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df.iloc[0:10,0:3]
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
# prompt: can you calculate measures of central tendency for salary olumn and measures of dispersion for salry column , also calculate skewness and kutosis ,

import pandas as pd

# Read the CSV file
df = pd.read_csv('Salaries.csv')

# Calculate measures of central tendency
mean_salary = df['salary'].mean()
median_salary = df['salary'].median()
mode_salary = df['salary'].mode()

# Calculate measures of dispersion
variance_salary = df['salary'].var()
std_salary = df['salary'].std()
min_salary = df['salary'].min()
max_salary = df['salary'].max()
range_salary = max_salary - min_salary

# Calculate skewness and kurtosis
skew_salary = df['salary'].skew()
kurt_salary = df['salary'].kurt()

# Print the results
print("Measures of Central Tendency:")
print(f"Mean Salary: {mean_salary:.2f}")
print(f"Median Salary: {median_salary:.2f}")
print(f"Mode Salary: {mode_salary.tolist()}")

print("\nMeasures of Dispersion:")
print(f"Variance of Salary: {variance_salary:.2f}")
print(f"Standard Deviation of Salary: {std_salary:.2f}")
print(f"Minimum Salary: {min_salary}")
print(f"Maximum Salary: {max_salary}")
print(f"Range of Salary: {range_salary}")

print("\nSkewness and Kurtosis:")
print(f"Skewness of Salary: {skew_salary:.2f}")
print(f"Kurtosis of Salary: {kurt_salary:.2f}")
# Out:
# Measures of Central Tendency:
# Mean Salary: 108023.78
# Median Salary: 104671.00
# Mode Salary: [92000]
#
# Measures of Dispersion:
# Variance of Salary: 800531254.04
# Standard Deviation of Salary: 28293.66
# Minimum Salary: 57800
# Maximum Salary: 186960
# Range of Salary: 129160
#
# Skewness and Kurtosis:
# Skewness of Salary: 0.45
# Kurtosis of Salary: -0.40

# %%
# prompt: use iloc function and select first 10 records and first 3 columns in dataset

import pandas as pd
df = pd.read_csv('Salaries.csv')
df.iloc[0:10, 0:3]
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['Accept'])
plt.xlabel('Accept')
plt.ylabel('Frequency')
plt.title('Histogram of Accept')
plt.show()

# %%
plt.hist(df1['SAT'])
plt.xlabel('SAT')
plt.ylabel('Frequency')
plt.title('Histogram of SAT')
plt.show()

# %%
sn.histplot(df1['Accept'])
plt.show()

# %%
sn.histplot(df1['SAT'])
plt.show()

# %%
plt.plot(df1['Accept'],df1['SAT'],'rs')
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Accept vs SAT')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(df1['Accept'],df1['Top10'],'rs')
plt.xlabel('Accept')
plt.ylabel('Top10')
plt.title('Accept vs Top10')
plt.show()

# %%
sn.pairplot(df1)

# %%
sn.pairplot(df1.iloc[:,1:3])

# %%
import warnings
warnings.filterwarnings('ignore')
sn.distplot(df1['Accept'])
plt.show()

# %%
plt.boxplot(df1['Accept'],vert=False)
plt.show()

# %%
# prompt: create a histogram using seaborn library on accept column , change the color to black , chnage the edges color to white

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df1 is already loaded as in your provided code
# If not, load it: df1 = pd.read_csv('Universities.csv')

sns.histplot(df1['Accept'], color='black', edgecolor='white')
plt.xlabel('Accept')
plt.ylabel('Frequency')
plt.title('Histogram of Accept')
plt.show()
